# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
sns.set_style('darkgrid')

# %%
matplotlib.rc('figure', titlesize='24')
matplotlib.rc('legend', fontsize='medium')
matplotlib.rc('axes', titlesize='22', titleweight='bold')
matplotlib.rc('xtick', labelsize='18')
matplotlib.rc('ytick', labelsize='18')
matplotlib.rc('axes', labelsize='20')
matplotlib.rc('font', size='18')

# %% [markdown]
# # Parameters

# %%
paramss = {
        "np": [50,100,200],
        "m" : [0.1,0.3,0.4,0.6,0.8],
        "t" : [3,5,7,10],
        "c" : [1,2,3,4],
        "me" : ["swap","opt"]
        }

# %%
params_np_t  =[
        {"np": 50, "t" : 3},
        {"np": 100, "t" : 3},
        {"np" : 150, "t" : 3},
        {"np" : 200, "t" : 3},
        {"np" : 250, "t" : 3},
        {"np" : 300, "t" : 3},
        {"np": 50, "t" : 5},
        {"np": 100, "t" : 5},
        {"np" : 150, "t" : 5},
        {"np" : 200, "t" : 5},
        {"np" : 250, "t" : 5},
        {"np" : 300, "t" : 5},
        {"np": 50, "t" : 7},
        {"np": 100, "t" : 7},
        {"np" : 150, "t" : 7},
        {"np" : 200, "t" : 7},
        {"np" : 250, "t" : 7},
        {"np" : 300, "t" : 7},
        {"np": 50, "t" : 10},
        {"np": 100, "t" : 10},
        {"np" : 150, "t" : 10},
        {"np" : 200, "t" : 10},
        {"np" : 250, "t" : 10},
        {"np" : 300, "t" : 10},
        ]

# %%
params_m = []

for j in paramss["m"]:
    params_m.append({"np": 200, "t" : 8 , "m" : j})

# %% [markdown]
# # Reading files and formating them

# %%
def params(x, dic):
    temp = x.split("\n")
    temp = list(map(lambda l : l.split(":"), temp))
    print(temp)
    if(temp[0] == ['']):
        temp.pop(0)
    toret = {
        'params': dic[int(temp[0][1])],
        'fitness' : float(temp[1][1])
    }
    return toret

# %% [markdown]
# # Tournament and pop size

# %%
myfile = open("tournAndPop.txt", "r")
data = myfile.read()
myfile.close()
data = data.split("#")
md = list(map(lambda l : params(l,params_np_t), data))

# %%
tp = {
    3 :[],
    5 : [],
    7 : [],
    10 : []
}
for k in md:
    tp[k['params']['t']].append((k['params']['np'],k['fitness']))

# %%
plt.figure(figsize=(20,10))
for l in tp :
    toprint = list(zip(*sorted(tp[l])))
    plt.plot(toprint[0],toprint[1], label = "Tournament size = "+str(l))
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

plt.xlabel("Nombre d'individus au sein de la population")
plt.ylabel("Fitness")
# Out:
# Text(0, 0.5, 'Fitness')

# %% [markdown]
# # Mutation

# %%
[0.1,0.3,0.4,0.6,0.8]
# Out:
# [0.1, 0.3, 0.4, 0.6, 0.8]

# %%
myfile = open("mutation.txt", "r")
data = myfile.read()
myfile.close()
data = data.split("#")
md = list(map(lambda l : params(l,params_m), data))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-131-e537c267f03f> in <module>
#       3 myfile.close()
#       4 data = data.split("#")
# ----> 5 md = list(map(lambda l : params(l,params_m), data))
#
# <ipython-input-131-e537c267f03f> in <lambda>(l)
#       3 myfile.close()
#       4 data = data.split("#")
# ----> 5 md = list(map(lambda l : params(l,params_m), data))
#
# <ipython-input-124-c6d55ba1f1eb> in params(x, dic)
#       5         temp.pop(0)
#       6     toret = {
# ----> 7         'params': dic[int(temp[0][1])],
#       8         'fitness' : float(temp[1][1])
#       9     }
#
# IndexError: list index out of range

# %%
tp = {
    0.1 :[],
    0.3: [],
    0.4: [],
    0.6: [],
    0.8: []
}
for k in md:
    tp[k['params']['t']].append((k['params']['np'],k['fitness']))
